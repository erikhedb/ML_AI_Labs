# %% [markdown]
# ## Lab 0
# This is a nice place to start just to get familiar with some of the packages used.
#
# As always its importamt to understand your data and make sure it becomes information.
#
# scikit-learn - We will use the scikit-learn package to get sample data
# numpy - as a start for math operations
# matlpotlib - for visualization

# %% [markdown]
# ### Example 1 - Data for linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression, make_classification
from sklearn.model_selection import train_test_split

#Get sample test data
X, y = make_regression(n_samples=100, n_features=2,n_informative=1,bias=0 ,noise=1, random_state=0)

# Divide into traning and verification sets
# Good general practice to pic random parts of the dataset for modell quality controll
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)


print("-------- DATA -------")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
print("----------------------")

plt.figure(figsize=(8,6))
plt.title("This is a plot title")
plt.xlabel("Sample data that are just data - in no way information och knowledge")
plt.ylabel("Dependent var")

plt.scatter(X[:,0],y,color="b", marker=".",s=10)
plt.scatter(X[:,1],y,color="r", marker=".",s=10)
# Out:
# -------- DATA -------
# X_train: (80, 2)
# y_train: (80,)
# X_test: (20, 2)
# y_test: (20,)
# ----------------------

# %% [markdown]
# ## Exmpel 2 - Data for classification / Logistical Regresson

# %%
plt.title("One informative feature, one cluster per class", fontsize="small")
X1, y = make_classification(n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1,random_state=1)

print("-------- DATA -------")
print(f"X1: {X1.shape}")
print(f"Y1: {y.shape}")
print("----------------------")

plt.scatter(X1[:, 0], X1[:, 1], marker="o", c=y, s=25, edgecolor="k")
# Out:
# -------- DATA -------
# X1: (100, 2)
# Y1: (100,)
# ----------------------

# %% [markdown]
# ## Matrix calculations uning numpy

# %%
import numpy as np

# The point
x1 = np.array([0,0])
x2 = np.array([4,3])

Adding an into to a np array
x3 = 10+x2

print(x3)
# Out:
# [14 13]
