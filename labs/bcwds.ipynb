# %% [markdown]
# # Scikit and Wisconsin Breast Cancer (Diagnostic) Data Set¶
#
# Load into a pandas frame - file downloaded from kaggle.com
#
# Decision Trees in Sci-kit

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import numpy as np

pd.set_option('display.max_columns', 100)
df= pd.read_csv('./data/bcw.csv',  index_col= None, na_values='?')

df = df.drop(['id','Unnamed: 32'], axis = 1)



df.head(6)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
# 5         M        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
# ...

# %%
#check if we have null values
print("List null values")
print(df.isnull().sum())
# Out:
# List null values
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
#Check the shape of the data
print(df.shape)
# Out:
# (569, 30)

# %%
y = df['diagnosis']
X = df.drop(['diagnosis'],axis = 1)

# Split into test and train data sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

print(f"X_train : {X_train.shape}")
print(f"y_train : {y_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_test : {y_test.shape}")
# Out:
# X_train : (455, 30)
# y_train : (455,)
# X_test : (114, 30)
# y_test : (114,)

# %%
#Random Forest Classifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)

print(f"Train Accuracy : {rfc.score(X_train,y_train)}")
print(f"Test Accuracy : {rfc.score(X_test,y_test)}")
# Out:
# Train Accuracy : 1.0
# Test Accuracy : 0.9210526315789473

# %% [markdown]
# ## Lets try Logistic Regression

# %%
# Is this an Overfitted model - Lets try logistic regresson

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=5000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
print(f"Train Score {lr.score(X_train,y_train)}")
print(f"Test Score  {lr.score(X_test,y_test)}")
# Out:
# Train Score 0.9604395604395605
# Test Score  0.9473684210526315

# %% [markdown]
# ## Lets try KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
nn = KNeighborsClassifier(n_neighbors=3)
nn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Predict 
y_pred = nn.predict(X_test)

# %%
## Calculate the quality 
acc = np.sum(y_pred == y_test) / len(y_test)
print(f"Acc: {acc}")

nn.score()
# Out:
# Acc: 0.9473684210526315
